# %%
import matplotlib.pyplot as plb
import seaborn as sns

# %%
# Data 로딩 --------------------------------
anscombe = sns.load_dataset('anscombe')
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe.head(), anscombe.tail()
# Out:
# (  dataset     x     y
#  0       I  10.0  8.04
#  1       I   8.0  6.95
#  2       I  13.0  7.58
#  3       I   9.0  8.81
#  4       I  11.0  8.33,
#     dataset     x      y
#  39      IV   8.0   5.25
#  40      IV  19.0  12.50
#  41      IV   8.0   5.56
#  42      IV   8.0   7.91
#  43      IV   8.0   6.89)

# %%
# 컬럼별로 값의 종류를 알고 싶다.

anscombe.dataset.unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
anscombe.x.unique()
# Out:
# array([10.,  8., 13.,  9., 11., 14.,  6.,  4., 12.,  7.,  5., 19.])

# %%
anscombe.y.unique()
# Out:
# array([ 8.04,  6.95,  7.58,  8.81,  8.33,  9.96,  7.24,  4.26, 10.84,
#         4.82,  5.68,  9.14,  8.14,  8.74,  8.77,  9.26,  8.1 ,  6.13,
#         3.1 ,  9.13,  7.26,  4.74,  7.46,  6.77, 12.74,  7.11,  7.81,
#         8.84,  6.08,  5.39,  8.15,  6.42,  5.73,  6.58,  5.76,  7.71,
#         8.47,  7.04,  5.25, 12.5 ,  5.56,  7.91,  6.89])

# %%
# dataset_1 = anscombe[anscombe['dataset'] =="I"]
anscombe['dataset'] =="I" #불린인덱싱
MASK  = anscombe['dataset'] =="I" #불린인덱싱

oneDF = anscombe[MASK] #트루인 것만 튀어나옴

# %%
oneDF.index, oneDF.columns

oneDF.x
# Out:
# 0     10.0
# 1      8.0
# 2     13.0
# 3      9.0
# 4     11.0
# 5     14.0
# 6      6.0
# 7      4.0
# 8     12.0
# 9      7.0
# 10     5.0
# Name: x, dtype: float64

# %%
# 데이터 시각화

# plb.figure()
plb.plot(oneDF.x)

# %%
import numpy as np
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plb.plot(x, y)

# %%
import matplotlib.pyplot as plb
import seaborn as sns

anscombe = sns.load_dataset('anscombe')

anscombe.info()

anscombe.head(), anscombe.tail()

anscombe.dataset.unique()

anscombe.x.unique()

anscombe.y.unique()

MASK = anscombe.dataset == 'I'
oneDF = anscombe[MASK]

oneDF.index

oneDF.columns

plb.plot(oneDF.y, 'ro--')
plb.title("[anscombe]")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
# Text(0.5, 1.0, '[anscombe]')

# %%
plb.plot(oneDF.x, oneDF.y, 'ro', oneDF.x, oneDF.y+5,'go---')
plb.xlabel("X")
plb.ylabel("y")
plb.title("[anscombe]")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 plb.plot(oneDF.x, oneDF.y, 'ro', oneDF.x, oneDF.y+5,'go---')
#       2 plb.xlabel("X")
#       3 plb.ylabel("y")
#
# File c:\Users\seo\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2740, in plot(scalex, scaley, data, *args, **kwargs)
#    2738 @_copy_docstring_and_deprecators(Axes.plot)
#    2739 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2740     return gca().plot(
#    2741         *args, scalex=scalex, scaley=scaley,
#    2742         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\seo\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
# ...

# %%
oneDF.plot('x','y')

# oneDF.plot(kind='bar','x')
# Out:
# <AxesSubplot: xlabel='x'>

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
anscombe.dataset.unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
fig = plb.figure()
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
axes1.plot(dataset_1['x'],dataset_1['y'])
axes2.plot(dataset_2['x'],dataset_2['y'])
axes3.plot(dataset_3['x'],dataset_3['y'])
axes4.plot(dataset_4['x'],dataset_4['y'])

# %%
fig
